# %% [markdown]
# #### Нелинейное уравнение
# ### Truffic flow model

# %%
import numpy as np
from matplotlib.pylab import mpl
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from matplotlib import animation
from IPython.display import HTML

# %%
def rho_green_light(nx,rho_light):
    rho = np.arange(nx) * 2 / nx * rho_light
    rho[int((nx-1)/2):] = 0
    return rho

# %%
nx = 81
nt = 30

dx = 4.0 / (nx-1)

x = np.linspace(0.0,4.0,nx)

rho_max = 10.
u_max = 1.
rho_light = 10.

rho = rho_green_light(nx, rho_light)

# %%
plt.plot(x, rho)

# %%
def computeF(u_max, rho_max, rho):
    return u_max*rho*(1-rho/rho_max)

# %%
def wave_speed(u_max, rho_max, rho):
    return u_max*(1-2*rho/rho_max)

# %% [markdown]
# #### Схема центральных разностей

# %%
def ftbs(rho,nt,dt,dx,rho_max,u_max):
    rho_n = np.zeros((nt,len(rho))) #двумерный массив
    rho_n[0,:] = rho.copy()
    
    for t in range(1, nt):
        F = computeF(u_max,rho_max,rho)
        rho_n[t,1:] = rho[1:] - dt/dx*(F[1:] - F[:-1])
        rho_n[t,0] = rho[0]
        rho = rho_n[t].copy()
        
    return rho_n

# %%
sigma = 1
dt = sigma*dx

rho_n = ftbs(rho,nt,dt,dx,rho_max,u_max)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_23368/2132205928.py:2: RuntimeWarning: overflow encountered in multiply
#   return u_max*rho*(1-rho/rho_max)
# C:\Users\user\AppData\Local\Temp/ipykernel_23368/3101399015.py:7: RuntimeWarning: invalid value encountered in subtract
#   rho_n[t,1:] = rho[1:] - dt/dx*(F[1:] - F[:-1])

# %%
plt.plot(x,rho_n[nt-1])

# %% [markdown]
# #### Схема Годунова

# %%
def rho_red_light(nx, rho_max, rho_in):
    rho = rho_max*np.ones(nx)
    rho[:int((nx-1)*0.75)] = rho_in
    return rho

# %%
nx = 81
nt = 30
dx = 4/(nx-1)

rho_in = 5
rho_max = 10
u_max = 1

x = np.linspace(0,4,nx)
rho = rho_red_light(nx, rho_max, rho_in)

# %%
def flux_TE(u_max, rho_max, rho_l, rho_r):
    rho_star = 0
    uw_l , uw_r = wave_speed(u_max, rho_max, np.array([rho_l, rho_r]))
    if uw_l >= uw_r :
        s = u_max*(1-(rho_l+rho_r)/rho_max)
        rho_star = rho_l if s > 0 else rho_r
    else:
        if uw_l > 0:
            rho_star = rho_l
        if uw_r < 0:
            rho_star = rho_r
        if (uw_l < 0) and (uw_r > 0):
            rho_star = rho_max/2
    return computeF(u_max, rho_max, rho_star)

# %%
def godunov(rho,nt,dt,dx,rho_max,u_max):
    rho_n = np.zeros((nt,len(rho))) #двумерный массив
    rho_n[0,:] = rho.copy()
    
    for t in range(1, nt):
        F = np.zeros(nx-1)
        for i in range (nx-1):
            F[i] = flux_TE(u_max,rho_max,rho[i],rho[i+1])
        rho_n[t,1:-1] = rho[1:-1] - dt/dx*(F[1:] - F[:-1])
        rho_n[t,0] = rho[0]
        rho_n[t,-1] = rho[-2]
        rho = rho_n[t].copy()
    return rho_n

# %%
sigma = 1
dt = sigma*dx / u_max

rho_n = godunov(rho,nt,dt,dx,rho_max,u_max)

# %%
fig = plt.figure();
ax = plt.axes(xlim=(0,4),ylim=(4.5,11),xlabel=('Distance'),ylabel=('Traffic density'));
line, = ax.plot([],[],'o-',color='#003366', lw=2);

sigma = 0.5
dt = sigma*dx/u_max

rho = rho_red_light(nx, rho_max, rho_in)
rho_n = godunov(rho,nt, dt, dx, rho_max, u_max)

anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0ba18b52467f4bd6afcf9e7789fa1b71">
#   <div class="anim-controls">
#     <input id="_anim_slider0ba18b52467f4bd6afcf9e7789fa1b71" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0ba18b52467f4bd6afcf9e7789fa1b71.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim0ba18b52467f4bd6afcf9e7789fa1b71.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select0ba18b52467f4bd6afcf9e7789fa1b71"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0ba18b52467f4bd6afcf9e7789fa1b71"
#              >
#       <label for="_anim_radio1_0ba18b52467f4bd6afcf9e7789fa1b71">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0ba18b52467f4bd6afcf9e7789fa1b71"
#              checked>
#       <label for="_anim_radio2_0ba18b52467f4bd6afcf9e7789fa1b71">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0ba18b52467f4bd6afcf9e7789fa1b71"
#              >
#       <label for="_anim_radio3_0ba18b52467f4bd6afcf9e7789fa1b71">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0ba18b52467f4bd6afcf9e7789fa1b71";
#     var slider_id = "_anim_slider0ba18b52467f4bd6afcf9e7789fa1b71";
#     var loop_select_id = "_anim_loop_select0ba18b52467f4bd6afcf9e7789fa1b71";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %%
plt.plot(x, rho, color='#003366', ls='-', lw=3)
plt.ylabel('Traffic density')
plt.xlabel('Distance')
plt.ylim(-0.5,11.);
plt.plot(x,rho_n[25])

# %% [markdown]
# #### Lax-Friedrichs Scheme

# %%
def rho_red_light(nx, rho_max, rho_in):
    rho = rho_max*np.ones(nx)
    rho[:int((nx-1)*0.75)] = rho_in
    return rho

# %%
nx = 81
nt = 30
dx = 4/(nx-1)

rho_in = 5
rho_max = 10
u_max = 1

x = np.linspace(0,4,nx)
rho = rho_red_light(nx, rho_max, rho_in)

plt.plot(x,rho)

# %%
def computeF(u_max, rho_max, rho):
    return u_max*rho*(1-rho/rho_max)

# %%
def animate(data):
    x - np.linspace(0,4,nx)
    y = data
    line.set_data(x,y)
    return line,

# %%
def laxfriedrichs(rho, nt, dt, dx, rho_max, u_max):
    rho_n = np.zeros((nt, len(rho)))
    rho_n[:,:] = rho.copy()
    
    for t in range(1,nt):
        F = computeF(u_max, rho_max, rho)
        rho_n[t,1:-1] = 0.5*(rho[2:] + rho[:-2]) - dt/(2*dx)*(F[2:] - F[:-2])
        rho_n[t, 0]= rho[0]
        rho_n[t, -1] = rho[-1]
        rho = rho_n[t].copy()
    return rho_n

# %%
sigma = 0.5
dt = sigma*dx/u_max

rho = rho_red_light(nx, rho_max, rho_in)
rho_n = laxfriedrichs(rho,nt, dt, dx, rho_max, u_max)

# %%
fig = plt.figure();
ax = plt.axes(xlim=(0,4),ylim=(4.5,11),xlabel=('Distance'),ylabel=('Traffic density'));
line, = ax.plot([],[],'-o',color='#003366', lw=2);

# %%
anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0087f4b4909844b7a222c324bc7cefd5">
#   <div class="anim-controls">
#     <input id="_anim_slider0087f4b4909844b7a222c324bc7cefd5" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0087f4b4909844b7a222c324bc7cefd5.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim0087f4b4909844b7a222c324bc7cefd5.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim0087f4b4909844b7a222c324bc7cefd5.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim0087f4b4909844b7a222c324bc7cefd5.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim0087f4b4909844b7a222c324bc7cefd5.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim0087f4b4909844b7a222c324bc7cefd5.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim0087f4b4909844b7a222c324bc7cefd5.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim0087f4b4909844b7a222c324bc7cefd5.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim0087f4b4909844b7a222c324bc7cefd5.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim0087f4b4909844b7a222c324bc7cefd5.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select0087f4b4909844b7a222c324bc7cefd5"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0087f4b4909844b7a222c324bc7cefd5"
#              >
#       <label for="_anim_radio1_0087f4b4909844b7a222c324bc7cefd5">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0087f4b4909844b7a222c324bc7cefd5"
#              checked>
#       <label for="_anim_radio2_0087f4b4909844b7a222c324bc7cefd5">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0087f4b4909844b7a222c324bc7cefd5"
#              >
#       <label for="_anim_radio3_0087f4b4909844b7a222c324bc7cefd5">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0087f4b4909844b7a222c324bc7cefd5";
#     var slider_id = "_anim_slider0087f4b4909844b7a222c324bc7cefd5";
#     var loop_select_id = "_anim_loop_select0087f4b4909844b7a222c324bc7cefd5";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# #### Lax-Wendroff Scheme

# %%
def Jacobian (u_max, rho_max, rho):
    return u_max*(1-2*rho/rho_max)

# %%
def laxwendroff(rho,nt,dt,dx,rho_max,u_max):
    rho_n = np.zeros((nt, len(rho)))
    rho_n[:,:] = rho.copy()
    
    for t in range(1,nt):
        F = computeF(u_max, rho_max, rho)
        J = Jacobian(u_max, rho_max, rho)
        rho_n[t,1:-1] = (rho[1:-1])- dt/(2*dx)*(F[2:] - F[:-2]) + dt**2/(4*dx**2)*((J[2:]+J[1:-1])*(F[2:]-F[1:-1]) - (J[1:-1] + J[:-2])*(F[1:-1] - F[:-2]))
        rho_n[t, 0]= rho[0]
        rho_n[t, -1] = rho[-1]
        rho = rho_n[t].copy()
    return rho_n

# %%
sigma = 0.5
dt = sigma*dx/u_max

rho = rho_red_light(nx, rho_max, rho_in)
rho_n = laxwendroff(rho,nt, dt, dx, rho_max, u_max)

# %%
anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge07a8b10e59240a997ca7671fdaf8278">
#   <div class="anim-controls">
#     <input id="_anim_slidere07a8b10e59240a997ca7671fdaf8278" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime07a8b10e59240a997ca7671fdaf8278.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime07a8b10e59240a997ca7671fdaf8278.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime07a8b10e59240a997ca7671fdaf8278.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime07a8b10e59240a997ca7671fdaf8278.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime07a8b10e59240a997ca7671fdaf8278.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime07a8b10e59240a997ca7671fdaf8278.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime07a8b10e59240a997ca7671fdaf8278.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime07a8b10e59240a997ca7671fdaf8278.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime07a8b10e59240a997ca7671fdaf8278.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime07a8b10e59240a997ca7671fdaf8278.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte07a8b10e59240a997ca7671fdaf8278"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e07a8b10e59240a997ca7671fdaf8278"
#              >
#       <label for="_anim_radio1_e07a8b10e59240a997ca7671fdaf8278">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e07a8b10e59240a997ca7671fdaf8278"
#              checked>
#       <label for="_anim_radio2_e07a8b10e59240a997ca7671fdaf8278">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e07a8b10e59240a997ca7671fdaf8278"
#              >
#       <label for="_anim_radio3_e07a8b10e59240a997ca7671fdaf8278">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge07a8b10e59240a997ca7671fdaf8278";
#     var slider_id = "_anim_slidere07a8b10e59240a997ca7671fdaf8278";
#     var loop_select_id = "_anim_loop_selecte07a8b10e59240a997ca7671fdaf8278";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA

# %% [markdown]
# #### MacCormac Scheme

# %%
def maccormac(rho, nt, dt, dx, rho_max, u_max):
    rho_n = np.zeros((nt,len(rho)))
    rho_star = np.empty_like(rho)
    rho_n[:,:] = rho.copy()
    rho_star = rho.copy()
    
    for t in range(1,nt):
        F = computeF(u_max, rho_max, rho)
        rho_star[:-1] = rho[:-1] - dt/dx*(F[1:] - F[:-1])
        Fstar = computeF(u_max, rho_max, rho_star)
        rho_n[t,1:] = 0.5 * (rho[1:] + rho_star[1:] - dt/dx * (Fstar[1:] - Fstar[:-1]))
        rho = rho_n[t].copy()
    return rho_n

# %%
fig = plt.figure();
ax = plt.axes(xlim=(0,4),ylim=(4.5,11),xlabel=('Distance'),ylabel=('Traffic density'));
line, = ax.plot([],[],'o-',color='#003366', lw=2);

# %%
sigma = 1
dt = sigma*dx/u_max

rho = rho_red_light(nx, rho_max, rho_in)
rho_n = maccormac(rho,nt, dt, dx, rho_max, u_max)

# %%
anim = animation.FuncAnimation(fig, animate, frames=rho_n, interval=50)
HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imga651e114ef614f3e8c269cd64b1c0479">
#   <div class="anim-controls">
#     <input id="_anim_slidera651e114ef614f3e8c269cd64b1c0479" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anima651e114ef614f3e8c269cd64b1c0479.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anima651e114ef614f3e8c269cd64b1c0479.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anima651e114ef614f3e8c269cd64b1c0479.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anima651e114ef614f3e8c269cd64b1c0479.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anima651e114ef614f3e8c269cd64b1c0479.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anima651e114ef614f3e8c269cd64b1c0479.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anima651e114ef614f3e8c269cd64b1c0479.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anima651e114ef614f3e8c269cd64b1c0479.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anima651e114ef614f3e8c269cd64b1c0479.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anima651e114ef614f3e8c269cd64b1c0479.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecta651e114ef614f3e8c269cd64b1c0479"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_a651e114ef614f3e8c269cd64b1c0479"
#              >
#       <label for="_anim_radio1_a651e114ef614f3e8c269cd64b1c0479">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_a651e114ef614f3e8c269cd64b1c0479"
#              checked>
#       <label for="_anim_radio2_a651e114ef614f3e8c269cd64b1c0479">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_a651e114ef614f3e8c269cd64b1c0479"
#              >
#       <label for="_anim_radio3_a651e114ef614f3e8c269cd64b1c0479">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga651e114ef614f3e8c269cd64b1c0479";
#     var slider_id = "_anim_slidera651e114ef614f3e8c269cd64b1c0479";
#     var loop_select_id = "_anim_loop_selecta651e114ef614f3e8c269cd64b1c0479";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8rg+JYAAAACXBIWXMAAAsT\
# AAALEwEAmpwYA
