# %%
import sympy as sp

# %%
x = sp.symbols('x')
y = sp.symbols('y')

A = sp.Matrix([[2, x, -y], [0, 1, x], [y, 5, 6]]);
det = A.det()
print(det)
print(det.subs([(x, 2), (y, -3)])) # not int!
#L = A.eigenvals()
#H = A.eigenvects() #takes VERY long to compute
# Out:
# x**2*y - 10*x + y**2 + 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6b9cfa688c1e> in <module>
#       7 #print(det.subs([(x, 2), (y, -3)])) # not int!
#       8 L = A.eigenvals()
# ----> 9 H = A.eigenvects()
#      10 print(H)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\matrices.py in eigenvects(self, error_when_incomplete, iszerofunc, **flags)
#     369
#     370     def eigenvects(self, error_when_incomplete=True, iszerofunc=_iszero, **flags):
# --> 371         return _eigenvects(self, error_when_incomplete=error_when_incomplete,
#     372                 iszerofunc=iszerofunc, **flags)
#     373
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\eigen.py in _eigenvects(M, error_when_incomplete, iszerofunc, chop, **flags)
#     351     ret = []
#     352     for val, mult in eigenvals:
# --> 353         vects = _eigenspace(M, val, iszerofunc=iszerofunc, simplify=simplify)
#     354         ret.append((val, mult, vects))
#     355
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\eigen.py in _eigenspace(M, eigenval, iszerofunc, simplify)
#     243     """Get a basis for the eigenspace for a particular eigenvalue"""
#     244     m   = M - M.eye(M.rows) * eigenval
# --> 245     ret = m.nullspace(iszerofunc=iszerofunc)
#     246
#     247     # The nullspace for a real eigenvalue should be non-trivial.
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\matrices.py in nullspace(self, simplify, iszerofunc)
#     341
#     342     def nullspace(self, simplify=False, iszerofunc=_iszero):
# --> 343         return _nullspace(self, simplify=simplify, iszerofunc=iszerofunc)
#     344
#     345     def rowspace(self, simplify=False):
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\subspaces.py in _nullspace(M, simplify, iszerofunc)
#      64     """
#      65
# ---> 66     reduced, pivots = M.rref(iszerofunc=iszerofunc, simplify=simplify)
#      67
#      68     free_vars = [i for i in range(M.cols) if i not in pivots]
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\matrices.py in rref(self, iszerofunc, simplify, pivots, normalize_last)
#     162     def rref(self, iszerofunc=_iszero, simplify=False, pivots=True,
#     163             normalize_last=True):
# --> 164         return _rref(self, iszerofunc=iszerofunc, simplify=simplify,
#     165             pivots=pivots, normalize_last=normalize_last)
#     166
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\reductions.py in _rref(M, iszerofunc, simplify, pivots, normalize_last)
#     303     simpfunc = simplify if isinstance(simplify, FunctionType) else _simplify
#     304
# --> 305     mat, pivot_cols, _ = _row_reduce(M, iszerofunc, simpfunc,
#     306             normalize_last, normalize=True, zero_above=True)
#     307
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\reductions.py in _row_reduce(M, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     125                 normalize=True, zero_above=True):
#     126
# --> 127     mat, pivot_cols, swaps = _row_reduce_list(list(M), M.rows, M.cols, M.one,
#     128             iszerofunc, simpfunc, normalize_last=normalize_last,
#     129             normalize=normalize, zero_above=zero_above)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\reductions.py in _row_reduce_list(mat, rows, cols, one, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#      66     while piv_col < cols and piv_row < rows:
#      67         pivot_offset, pivot_val, \
# ---> 68         assumed_nonzero, newly_determined = _find_reasonable_pivot(
#      69                 get_col(piv_col)[piv_row:], iszerofunc, simpfunc)
#      70
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\matrices\determinant.py in _find_reasonable_pivot(col, iszerofunc, simpfunc)
#      99         if possible_zeros[i] is not None:
#     100             continue
# --> 101         if x.equals(S.Zero):
#     102             # ``.iszero`` may return False with
#     103             # an implicit assumption (e.g., ``x.equals(0)``
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in equals(self, other, failing_expression)
#     741             return False
#     742
# --> 743         constant = diff.is_constant(simplify=False, failing_number=True)
#     744
#     745         if constant is False:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in is_constant(self, *wrt, **flags)
#     664                 except ZeroDivisionError:
#     665                     b = None
# --> 666                 if b is not None and b is not S.NaN and b.equals(a) is False:
#     667                     return False
#     668                 # try random real
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in equals(self, other, failing_expression)
#     788                     # to see if we are in the right ballpark or not and if so
#     789                     # *then* the simplification will be attempted.
# --> 790                     sol = solve(diff, s, simplify=False)
#     791                     if sol:
#     792                         if s in sol:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in solve(f, *symbols, **flags)
#    1095     ###########################################################################
#    1096     if bare_f:
# -> 1097         solution = _solve(f[0], *symbols, **flags)
#    1098     else:
#    1099         solution = _solve_system(f, symbols, **flags)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1383                 result = set()
#    1384                 break
# -> 1385             soln = _solve(m, symbol, **flags)
#    1386             result.update(set(soln))
#    1387         result = list(result)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1688                     isym, ieq = cov
#    1689                     inv = _solve(ieq, symbol, **flags)[0]
# -> 1690                     rv = {inv.subs(isym, xi) for xi in _solve(eq, isym, **flags)}
#    1691                 else:
#    1692                     try:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1688                     isym, ieq = cov
#    1689                     inv = _solve(ieq, symbol, **flags)[0]
# -> 1690                     rv = {inv.subs(isym, xi) for xi in _solve(eq, isym, **flags)}
#    1691                 else:
#    1692                     try:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1706         flags.pop('tsolve', None)  # allow tsolve to be used on next pass
#    1707         try:
# -> 1708             soln = _tsolve(f_num, symbol, **flags)
#    1709             if soln is not None:
#    1710                 result = soln
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _tsolve(eq, sym, **flags)
#    2674         rewrite = lhs.rewrite(exp)
#    2675         if rewrite != lhs:
# -> 2676             return _solve(rewrite - rhs, sym, **flags)
#    2677     except NotImplementedError:
#    2678         pass
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in _solve(f, *symbols, **flags)
#    1680         if flags.pop('_unrad', True):
#    1681             try:
# -> 1682                 u = unrad(f_num, symbol)
#    1683             except (ValueError, NotImplementedError):
#    1684                 u = False
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in unrad(eq, *syms, **flags)
#    3530
#    3531     flags.update(dict(cov=cov, n=len(rterms), rpt=rpt))
# -> 3532     neq = unrad(eq, *syms, **flags)
#    3533     if neq:
#    3534         eq, cov = neq
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in unrad(eq, *syms, **flags)
#    3530
#    3531     flags.update(dict(cov=cov, n=len(rterms), rpt=rpt))
# -> 3532     neq = unrad(eq, *syms, **flags)
#    3533     if neq:
#    3534         eq, cov = neq
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\solvers\solvers.py in unrad(eq, *syms, **flags)
#    3296         eq, d = eq.as_numer_denom()
#    3297
# -> 3298     eq = _mexpand(eq, recursive=True)
#    3299     if eq.is_number:
#    3300         return
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\function.py in _mexpand(expr, recursive)
#    2836     was = None
#    2837     while was != expr:
# -> 2838         was, expr = expr, expand_mul(expand_multinomial(expr))
#    2839         if not recursive:
#    2840             break
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\function.py in expand_multinomial(expr, deep)
#    2877
#    2878     """
# -> 2879     return sympify(expr).expand(deep=deep, mul=False, power_exp=False,
#    2880     power_base=False, basic=False, multinomial=True, log=False)
#    2881
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3577             if use_hint:
#    3578                 hint = '_eval_expand_' + hint
# -> 3579                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3580
#    3581         while True:
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3510             sargs = []
#    3511             for arg in expr.args:
# -> 3512                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3513                 hit |= arghit
#    3514                 sargs.append(arg)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3510             sargs = []
#    3511             for arg in expr.args:
# -> 3512                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3513                 hit |= arghit
#    3514                 sargs.append(arg)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3510             sargs = []
#    3511             for arg in expr.args:
# -> 3512                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3513                 hit |= arghit
#    3514                 sargs.append(arg)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3510             sargs = []
#    3511             for arg in expr.args:
# -> 3512                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3513                 hit |= arghit
#    3514                 sargs.append(arg)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3510             sargs = []
#    3511             for arg in expr.args:
# -> 3512                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3513                 hit |= arghit
#    3514                 sargs.append(arg)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\expr.py in _expand_hint(expr, hint, deep, **hints)
#    3518
#    3519         if hasattr(expr, hint):
# -> 3520             newexpr = getattr(expr, hint)(**hints)
#    3521             if newexpr != expr:
#    3522                 return (newexpr, True)
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\core\power.py in _eval_expand_multinomial(self, **hints)
#    1159                 from sympy import multinomial_coefficients
#    1160                 from sympy.polys.polyutils import basic_from_dict
# -> 1161                 expansion_dict = multinomial_coefficients(len(p), n)
#    1162                 # in our example: {(3, 0): 1, (1, 2): 3, (0, 3): 1, (2, 1): 3}
#    1163                 # and now construct the expression.
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\ntheory\multinomial.py in multinomial_coefficients(m, n)
#      91         return binomial_coefficients(n)
#      92     if m >= 2*n and n > 1:
# ---> 93         return dict(multinomial_coefficients_iterator(m, n))
#      94     t = [n] + [0] * (m - 1)
#      95     r = {tuple(t): 1}
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sympy\ntheory\multinomial.py in multinomial_coefficients_iterator(m, n, _tuple)
#     186             t1 = _tuple(t)
#     187             b = _tuple(filter(None, t1))
# --> 188             yield (t1, mc[b])
#
# KeyboardInterrupt:
